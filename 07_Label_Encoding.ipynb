# %% [markdown]
# ## Label Encoding
# - converting the labels into numeric form

# %%
# importing the Dependencies
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Label Encoding of Breast Cancer Dataset
# loading the data from csv to pandas dataframe
cancer = pd.read_csv("Datasets\\breast_cancer.csv")

# %%
cancer.shape
# Out:
# (569, 32)

# %%
cancer.head()
# Out:
#    id  mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0   0        17.99         10.38          122.80     1001.0          0.11840
# 1   1        20.57         17.77          132.90     1326.0          0.08474
# 2   2        19.69         21.25          130.00     1203.0          0.10960
# 3   3        11.42         20.38           77.58      386.1          0.14250
# 4   4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  ...  \
# 0           0.27760          0.3001              0.14710         0.2419  ...
# 1           0.07864          0.0869              0.07017         0.1812  ...
# 2           0.15990          0.1974              0.12790         0.2069  ...
# 3           0.28390          0.2414              0.10520         0.2597  ...
# 4           0.13280          0.1980              0.10430         0.1809  ...
#
# ...

# %%
#finding the count of different labels
cancer["diagnosis"].value_counts()
# Out:
# diagnosis
# Malignant    357
# Benign       212
# Name: count, dtype: int64

# %% [markdown]
# Can't I just change the labels in the excel itself using the if conditional? C'mon lol😭🤣

# %%
# load the label Encoder function
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(cancer.diagnosis)

# %%
# appending the labels to the DataFrame
cancer["target"] = labels

# %%
cancer.head()
# Out:
#    id  mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0   0        17.99         10.38          122.80     1001.0          0.11840
# 1   1        20.57         17.77          132.90     1326.0          0.08474
# 2   2        19.69         21.25          130.00     1203.0          0.10960
# 3   3        11.42         20.38           77.58      386.1          0.14250
# 4   4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  ...  \
# 0           0.27760          0.3001              0.14710         0.2419  ...
# 1           0.07864          0.0869              0.07017         0.1812  ...
# 2           0.15990          0.1974              0.12790         0.2069  ...
# 3           0.28390          0.2414              0.10520         0.2597  ...
# 4           0.13280          0.1980              0.10430         0.1809  ...
#
# ...

# %% [markdown]
# ### 0 --> Benign
# ### 1 --> Malignant

# %%
cancer["target"].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64
